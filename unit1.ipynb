# %% [markdown]
# # Unit 1: Train your first Deep Reinforcement Learning Agent 🤖
#
# ![Cover](https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/thumbnail.jpg)
#
# In this notebook, you'll train your **first Deep Reinforcement Learning agent** a Lunar Lander agent that will learn to **land correctly on the Moon 🌕**. Using [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) a Deep Reinforcement Learning library, share them with the community, and experiment with different configurations
#
# ⬇️ Here is an example of what **you will achieve in just a couple of minutes.** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - [LunarLander-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ### The library used 📚
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Gymnasium**, the environment library.
# - Be able to use **Stable-Baselines3**, the deep reinforcement learning library.
# - Be able to **push your trained agent to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
# - 🎓 **Earn a certificate of completion** by completing 80% of the assignments.
#
# And more!
#
# Check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
# The best way to keep in touch and ask questions is **to join our discord server** to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
#
# Before diving into the notebook, you need to:
#
# 🔲 📝 **[Read Unit 0](https://huggingface.co/deep-rl-course/unit0/introduction)** that gives you all the **information about the course and helps you to onboard** 🤗
#
# 🔲 📚 **Develop an understanding of the foundations of Reinforcement learning** (RL process, Rewards hypothesis...) by [reading Unit 1](https://huggingface.co/deep-rl-course/unit1/introduction).

# %% [markdown]
# ## A small recap of Deep Reinforcement Learning 📚
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# Let's do a small recap on what we learned in the first Unit:
#
# - Reinforcement Learning is a **computational approach to learning from actions**. We build an agent that learns from the environment by **interacting with it through trial and error** and receiving rewards (negative or positive) as feedback.
#
# - The goal of any RL agent is to **maximize its expected cumulative reward** (also called expected return) because RL is based on the _reward hypothesis_, which is that all goals can be described as the maximization of an expected cumulative reward.
#
# - The RL process is a **loop that outputs a sequence of state, action, reward, and next state**.
#
# - To calculate the expected cumulative reward (expected return), **we discount the rewards**: the rewards that come sooner (at the beginning of the game) are more probable to happen since they are more predictable than the long-term future reward.
#
# - To solve an RL problem, you want to **find an optimal policy**; the policy is the "brain" of your AI that will tell us what action to take given a state. The optimal one is the one that gives you the actions that max the expected return.
#
# There are **two** ways to find your optimal policy:
#
# - By **training your policy directly**: policy-based methods.
# - By **training a value function** that tells us the expected return the agent will get at each state and use this function to define our policy: value-based methods.
#
# - Finally, we spoke about Deep RL because **we introduce deep neural networks to estimate the action to take (policy-based) or to estimate the value of a state (value-based) hence the name "deep."**

# %% [markdown]
# # Let's train our first Deep Reinforcement Learning agent and upload it to the Hub 🚀
#
# ## Get a certificate 🎓
#
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
#
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Install dependencies and create a virtual screen 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones.
#
# - `gymnasium[box2d]`: Contains the LunarLander-v2 environment 🌛
# - `stable-baselines3[extra]`: The deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
#
# To make things easier, we created a script to install all these dependencies.

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.

# %% [markdown]
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install virtual screen libraries and create and run a virtual screen 🖥

# %%
# !pip install stable-baselines3==2.0.0a5
# !pip install swig
# !pip install gymnasium
# !pip install box2d-py
# !pip install huggingface_sb3
# Out:
# Requirement already satisfied: stable-baselines3==2.0.0a5 in /usr/local/lib/python3.12/dist-packages (2.0.0a5)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (2.0.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (2.9.0+cu128)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (3.10.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->stable-baselines3==2.0.0a5) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5) (3.0.3)
# Requirement already satisfied: swig in /usr/local/lib/python3.12/dist-packages (4.4.1)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.12/dist-packages (2.3.8)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (0.36.2)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (6.0.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (26.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2026.1.4)

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (3,337 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# To make sure the new installed libraries are used, **sometimes it's required to restart the notebook runtime**. The next cell will force the **runtime to crash, so you'll need to connect again and run the code starting from here**. Thanks to this trick, **we will be able to run our virtual screen.**

# %%
import os
os.kill(os.getpid(), 9)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Import the packages 📦
#
# One additional library we import is huggingface_hub **to be able to upload and download trained models from the hub**.
#
#
# The Hugging Face Hub 🤗 works as a central place where anyone can share and explore models and datasets. It has versioning, metrics, visualizations and other features that will allow you to easily collaborate with others.
#
# You can see here all the Deep reinforcement Learning models available here👉 https://huggingface.co/models?pipeline_tag=reinforcement-learning&sort=downloads

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Understand Gymnasium and how it works 🤖
#
# 🏋 The library containing our environment is called Gymnasium.
# **You'll use Gymnasium a lot in Deep Reinforcement Learning.**
#
# Gymnasium is the **new version of Gym library** [maintained by the Farama Foundation](https://farama.org/).
#
# The Gymnasium library provides two things:
#
# - An interface that allows you to **create RL environments**.
# - A **collection of environments** (gym-control, atari, box2D...).
#
# Let's look at an example, but first let's recall the RL loop.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# At each step:
# - Our Agent receives a **state (S0)** from the **Environment** — we receive the first frame of our game (Environment).
# - Based on that **state (S0),** the Agent takes an **action (A0)** — our Agent will move to the right.
# - The environment transitions to a **new** **state (S1)** — new frame.
# - The environment gives some **reward (R1)** to the Agent — we’re not dead *(Positive Reward +1)*.
#
#
# With Gymnasium:
#
# 1️⃣ We create our environment using `gymnasium.make()`
#
# 2️⃣ We reset the environment to its initial state with `observation = env.reset()`
#
# At each step:
#
# 3️⃣ Get an action using our model (in our example we take a random action)
#
# 4️⃣ Using `env.step(action)`, we perform this action in the environment and get
# - `observation`: The new state (st+1)
# - `reward`: The reward we get after executing the action
# - `terminated`: Indicates if the episode terminated (agent reach the terminal state)
# - `truncated`: Introduced with this new version, it indicates a timelimit or if an agent go out of bounds of the environment for instance.
# - `info`: A dictionary that provides additional information (depends on the environment).
#
# For more explanations check this 👉 https://gymnasium.farama.org/api/env/#gymnasium.Env.step
#
# If the episode is terminated:
# - We reset the environment to its initial state with `observation = env.reset()`
#
# **Let's look at an example!** Make sure to read the code

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# Action taken: 1
# Action taken: 3
# Action taken: 3
# Action taken: 0
# Action taken: 2
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 1
# Action taken: 3
# Action taken: 3
# Action taken: 0
# Action taken: 2
# Action taken: 0
# Action taken: 2
# Action taken: 2
# Action taken: 0
# Action taken: 2
# Action taken: 3
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Create the LunarLander environment 🌛 and understand how it works
#
# ### [The environment 🎮](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# In this first tutorial, we’re going to train our agent, a [Lunar Lander](https://gymnasium.farama.org/environments/box2d/lunar_lander/), **to land correctly on the moon**. To do that, the agent needs to learn **to adapt its speed and position (horizontal, vertical, and angular) to land correctly.**
#
# ---
#
#
# 💡 A good habit when you start to use an environment is to check its documentation
#
# 👉 https://gymnasium.farama.org/environments/box2d/lunar_lander/
#
# ---

# %% [markdown]
# Let's see what the Environment looks like:

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-86.25728    -61.408978    -0.9695993   -0.09429116  -1.0679649
#   -3.4709306    0.69923425   0.6730642 ]

# %% [markdown]
# We see with `Observation Space Shape (8,)` that the observation is a vector of size 8, where each value contains different information about the lander:
# - Horizontal pad coordinate (x)
# - Vertical pad coordinate (y)
# - Horizontal speed (x)
# - Vertical speed (y)
# - Angle
# - Angular speed
# - If the left leg contact point has touched the land (boolean)
# - If the right leg contact point has touched the land (boolean)

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 3

# %% [markdown]
# The action space (the set of possible actions the agent can take) is discrete with 4 actions available 🎮:
#
# - Action 0: Do nothing,
# - Action 1: Fire left orientation engine,
# - Action 2: Fire the main engine,
# - Action 3: Fire right orientation engine.
#
# Reward function (the function that will give a reward at each timestep) 💰:
#
# After every step a reward is granted. The total reward of an episode is the **sum of the rewards for all the steps within that episode**.
#
# For each step, the reward:
#
# - Is increased/decreased the closer/further the lander is to the landing pad.
# -  Is increased/decreased the slower/faster the lander is moving.
# - Is decreased the more the lander is tilted (angle not horizontal).
# - Is increased by 10 points for each leg that is in contact with the ground.
# - Is decreased by 0.03 points each frame a side engine is firing.
# - Is decreased by 0.3 points each frame the main engine is firing.
#
# The episode receive an **additional reward of -100 or +100 points for crashing or landing safely respectively.**
#
# An episode is **considered a solution if it scores at least 200 points.**

# %% [markdown]
# #### Vectorized Environment
#
# - We create a vectorized environment (a method for stacking multiple independent environments into a single environment) of 16 environments, this way, **we'll have more diverse experiences during the training.**

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Create the Model 🤖
# - We have studied our environment and we understood the problem: **being able to land the Lunar Lander to the Landing Pad correctly by controlling left, right and main orientation engine**. Now let's build the algorithm we're going to use to solve this Problem 🚀.
#
# - To do so, we're going to use our first Deep RL library, [Stable Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/).
#
# - SB3 is a set of **reliable implementations of reinforcement learning algorithms in PyTorch**.
#
# ---
#
# 💡 A good habit when using a new library is to dive first on the documentation: https://stable-baselines3.readthedocs.io/en/master/ and then try some tutorials.
#
# ----

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/sb3.png" alt="Stable Baselines3">

# %% [markdown]
# To solve this problem, we're going to use SB3 **PPO**. [PPO (aka Proximal Policy Optimization) is one of the SOTA (state of the art) Deep Reinforcement Learning algorithms that you'll study during this course](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#example%5D).
#
# PPO is a combination of:
# - *Value-based reinforcement learning method*: learning an action-value function that will tell us the **most valuable action to take given a state and action**.
# - *Policy-based reinforcement learning method*: learning a policy that will **give us a probability distribution over actions**.

# %% [markdown]
# Stable-Baselines3 is easy to set up:
#
# 1️⃣ You **create your environment** (in our case it was done above)
#
# 2️⃣ You define the **model you want to use and instantiate this model** `model = PPO("MlpPolicy")`
#
# 3️⃣ You **train the agent** with `model.learn` and define the number of training timesteps
#
# ```
# # Create environment
# env = gym.make('LunarLander-v2')
#
# # Instantiate the agent
# model = PPO('MlpPolicy', env, verbose=1)
# # Train the agent
# model.learn(total_timesteps=int(2e5))
# ```

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Train the PPO agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~20min, but you can use fewer timesteps if you just want to try it out.
# - During the training, take a ☕ break you deserved it 🤗

# %%
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.6     |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    fps             | 3763     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 16384    |
# ---------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 91.9           |
# |    ep_rew_mean          | -149           |
# | time/                   |                |
# |    fps                  | 2391           |
# |    iterations           | 2              |
# |    time_elapsed         | 13             |
# |    total_timesteps      | 32768          |
# | train/                  |                |
# |    approx_kl            | 0.004537595    |
# |    clip_fraction        | 0.0327         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.38          |
# |    explained_variance   | -0.00071024895 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.51e+03       |
# |    n_updates            | 4              |
# |    policy_gradient_loss | -0.00494       |
# |    value_loss           | 4.02e+03       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.7         |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.006829921  |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.006549239 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 681          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 2.38e+03     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 97             |
# |    ep_rew_mean          | -136           |
# | time/                   |                |
# |    fps                  | 2066           |
# |    iterations           | 4              |
# |    time_elapsed         | 31             |
# |    total_timesteps      | 65536          |
# | train/                  |                |
# |    approx_kl            | 0.0061687455   |
# |    clip_fraction        | 0.0438         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.36          |
# |    explained_variance   | -0.00047183037 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 336            |
# |    n_updates            | 12             |
# |    policy_gradient_loss | -0.00329       |
# |    value_loss           | 1.18e+03       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 102            |
# |    ep_rew_mean          | -118           |
# | time/                   |                |
# |    fps                  | 2006           |
# |    iterations           | 5              |
# |    time_elapsed         | 40             |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | 0.007566154    |
# |    clip_fraction        | 0.0417         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.36          |
# |    explained_variance   | -0.00020241737 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 386            |
# |    n_updates            | 16             |
# |    policy_gradient_loss | -0.0047        |
# |    value_loss           | 977            |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -87.5         |
# | time/                   |               |
# |    fps                  | 1950          |
# |    iterations           | 6             |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.007696687   |
# |    clip_fraction        | 0.0798        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.0015956163 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 274           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00527      |
# |    value_loss           | 633           |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 116            |
# |    ep_rew_mean          | -66.7          |
# | time/                   |                |
# |    fps                  | 1896           |
# |    iterations           | 7              |
# |    time_elapsed         | 60             |
# |    total_timesteps      | 114688         |
# | train/                  |                |
# |    approx_kl            | 0.00878974     |
# |    clip_fraction        | 0.0531         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.3           |
# |    explained_variance   | -0.00011301041 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 170            |
# |    n_updates            | 24             |
# |    policy_gradient_loss | -0.00512       |
# |    value_loss           | 450            |
# --------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -52.6       |
# | time/                   |             |
# |    fps                  | 1865        |
# |    iterations           | 8           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009966642 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.09439075  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 261         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 356         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | -38.3       |
# | time/                   |             |
# |    fps                  | 1805        |
# |    iterations           | 9           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.007418828 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.1670022   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 276         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | -19.7        |
# | time/                   |              |
# |    fps                  | 1788         |
# |    iterations           | 10           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0055507114 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.33421546   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 181          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 322          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | -5.31       |
# | time/                   |             |
# |    fps                  | 1712        |
# |    iterations           | 11          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008128425 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.3364687   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 342         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | -0.42        |
# | time/                   |              |
# |    fps                  | 1595         |
# |    iterations           | 12           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0071981717 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.5163659    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 108          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 278          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 1485         |
# |    iterations           | 13           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0054867966 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.5911939    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 272          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 1414         |
# |    iterations           | 14           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0055480795 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.67260706   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.7         |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 222          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 1333         |
# |    iterations           | 15           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0049882424 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.7419331    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.1         |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 197          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 433          |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 1270         |
# |    iterations           | 16           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0061926404 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.78281283   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 134          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 161          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 503         |
# |    ep_rew_mean          | 22.7        |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 17          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.003160513 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.8031963   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.4        |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.000926   |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | 34.3        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 18          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.007251779 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.84544826  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.3        |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | 43.5         |
# | time/                   |              |
# |    fps                  | 1131         |
# |    iterations           | 19           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0051438743 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.9121888    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 65.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 688         |
# |    ep_rew_mean          | 55.3        |
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 20          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.010013517 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.9170939   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 55.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | 60.3         |
# | time/                   |              |
# |    fps                  | 1067         |
# |    iterations           | 21           |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0042893724 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.907668     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.3         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000717    |
# |    value_loss           | 79.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 776         |
# |    ep_rew_mean          | 73.2        |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 22          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005970635 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.86027426  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.8        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 788         |
# |    ep_rew_mean          | 79          |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 23          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.004273097 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.9353753   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.8        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.000713   |
# |    value_loss           | 54.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 800          |
# |    ep_rew_mean          | 77.4         |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 24           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0034988772 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.9073567    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.7         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 804         |
# |    ep_rew_mean          | 86.6        |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 25          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.008987663 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.92435575  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 70          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 843          |
# |    ep_rew_mean          | 93.3         |
# | time/                   |              |
# |    fps                  | 974          |
# |    iterations           | 26           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0047958996 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.9491115    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 53.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 865          |
# |    ep_rew_mean          | 97.3         |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 27           |
# |    time_elapsed         | 461          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0040124212 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.9514519    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.8         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 45.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 878          |
# |    ep_rew_mean          | 97           |
# | time/                   |              |
# |    fps                  | 945          |
# |    iterations           | 28           |
# |    time_elapsed         | 485          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0058311103 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.95752126   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.56         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 35.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 29           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0048220074 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.95339024   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 35.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 934        |
# |    ep_rew_mean          | 114        |
# | time/                   |            |
# |    fps                  | 924        |
# |    iterations           | 30         |
# |    time_elapsed         | 531        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.00556467 |
# |    clip_fraction        | 0.0303     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.970914   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12         |
# |    n_updates            | 116        |
# |    policy_gradient_loss | -0.00193   |
# |    value_loss           | 28.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 914          |
# |    iterations           | 31           |
# |    time_elapsed         | 555          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0042751515 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.97748804   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.07         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 18.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 903         |
# |    iterations           | 32          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.003970078 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.9841606   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.000956   |
# |    value_loss           | 15.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 967          |
# |    ep_rew_mean          | 124          |
# | time/                   |              |
# |    fps                  | 894          |
# |    iterations           | 33           |
# |    time_elapsed         | 604          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0057497425 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.98750514   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.1          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 13.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 964          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 34           |
# |    time_elapsed         | 629          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0054360535 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.9804937    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.9         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 21.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 35          |
# |    time_elapsed         | 652         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.004749055 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.9731231   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.000464   |
# |    value_loss           | 30          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 953         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 36          |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.005846181 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0.98447514  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.27        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000279   |
# |    value_loss           | 18.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 863          |
# |    iterations           | 37           |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0038661773 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.9677998    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 42.6         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 953       |
# |    ep_rew_mean          | 134       |
# | time/                   |           |
# |    fps                  | 856       |
# |    iterations           | 38        |
# |    time_elapsed         | 726       |
# |    total_timesteps      | 622592    |
# | train/                  |           |
# |    approx_kl            | 0.0040036 |
# |    clip_fraction        | 0.0381    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.962    |
# |    explained_variance   | 0.9920013 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.23      |
# |    n_updates            | 148       |
# |    policy_gradient_loss | -0.000367 |
# |    value_loss           | 8.21      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 39          |
# |    time_elapsed         | 751         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.004243464 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.9951837   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.000723   |
# |    value_loss           | 4.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 981         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 40          |
# |    time_elapsed         | 776         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.003476971 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.9946745   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000838   |
# |    value_loss           | 6.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 989         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 41          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.004650128 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 0.99550015  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.572       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000785   |
# |    value_loss           | 4.43        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 42           |
# |    time_elapsed         | 824          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0045452914 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0.9953557    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 5.46         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 43           |
# |    time_elapsed         | 850          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0037933984 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | 0.9961897    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.21         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 4.66         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 44           |
# |    time_elapsed         | 873          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0030620564 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.9964635    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5          |
# |    n_updates            | 172          |
# |    policy_gradient_loss | 0.000328     |
# |    value_loss           | 4.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 45          |
# |    time_elapsed         | 896         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.004054647 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.9969326   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000921   |
# |    value_loss           | 3.84        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 46           |
# |    time_elapsed         | 919          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0026942429 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.98860425   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000468     |
# |    value_loss           | 11.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 47          |
# |    time_elapsed         | 940         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.004059811 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.99712527  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | 0.000447    |
# |    value_loss           | 3.08        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 977          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 48           |
# |    time_elapsed         | 963          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0032556958 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.9813021    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.15         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000591    |
# |    value_loss           | 24.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 49          |
# |    time_elapsed         | 986         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.003889541 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.9969357   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | 0.000163    |
# |    value_loss           | 3.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 977          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 50           |
# |    time_elapsed         | 1007         |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0038344353 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0.9982342    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000616    |
# |    value_loss           | 2.54         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 51          |
# |    time_elapsed         | 1030        |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.005311896 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.9978119   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.894       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000961   |
# |    value_loss           | 2.72        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 52           |
# |    time_elapsed         | 1052         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0032446287 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.9979772    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | 0.000251     |
# |    value_loss           | 2.62         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 53           |
# |    time_elapsed         | 1074         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0033728562 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.9980932    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.532        |
# |    n_updates            | 208          |
# |    policy_gradient_loss | 0.000189     |
# |    value_loss           | 2.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 978          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 54           |
# |    time_elapsed         | 1097         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0050827092 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.9986474    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.626        |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 0.000437     |
# |    value_loss           | 2            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 55          |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.005495429 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0.96770793  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.47        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.000179   |
# |    value_loss           | 41.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 946          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 56           |
# |    time_elapsed         | 1138         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0032319287 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.95259315   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.47         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000706    |
# |    value_loss           | 85.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 921          |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 57           |
# |    time_elapsed         | 1159         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0038705347 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0.96265244   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.29         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 62.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 868          |
# |    ep_rew_mean          | 181          |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 58           |
# |    time_elapsed         | 1177         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0029979474 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | 0.94879895   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 104          |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.000346    |
# |    value_loss           | 99.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 788          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 59           |
# |    time_elapsed         | 1197         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0058061704 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.89946663   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.7         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 202          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 636          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 60           |
# |    time_elapsed         | 1213         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0045662634 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.699       |
# |    explained_variance   | 0.8432102    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 286          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 61           |
# |    time_elapsed         | 1229         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0071234554 |
# |    clip_fraction        | 0.0848       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.79758847   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 321          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 62          |
# |    time_elapsed         | 1244        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.010830607 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0.74563074  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 153         |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 333         |
# -----------------------------------------

# %% [markdown]
# ## Evaluate the agent 📈
# - Remember to wrap the environment in a [Monitor](https://stable-baselines3.readthedocs.io/en/master/common/monitor.html).
# - Now that our Lunar Lander agent is trained 🚀, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`.
# - To fill that part you need to [check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)
# - In the next step,  we'll see **how to automatically evaluate and share your agent to compete in a leaderboard, but for now let's do it ourselves**
#
#
# 💡 When you evaluate your agent, you should not use your training environment but create an evaluation environment.

# %%
eval_env = Monitor(gym.make("LunarLander-v2", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=269.51 +/- 31.025296327401136

# %% [markdown]
# ## Publish our trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20
#
# Here's an example of a Model Card (with Space Invaders):

# %% [markdown]
# By using `package_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account on Hugging Face ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from getpass import getpass
token = getpass("Enter your HuggingFace token: ")

# %%
! hf auth login --token {token}
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# The token `reinforcement-learning-tutorial-with-hugging-face` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `reinforcement-learning-tutorial-with-hugging-face`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# Let's fill the `package_to_hub` function:
# - `model`: our trained model.
# - `model_name`: the name of the trained model that we defined in `model_save`
# - `model_architecture`: the model architecture we used, in our case PPO
# - `env_id`: the name of the environment, in our case `LunarLander-v2`
# - `eval_env`: the evaluation environment defined in eval_env
# - `repo_id`: the name of the Hugging Face Hub Repository that will be created/updated `(repo_id = {username}/{repo_name})`
#
# 💡 **A good name is {username}/{model_architecture}-{env_id}**
#
# - `commit_message`: message of the commit

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "0x46455/ppo-LunarLander-v2" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmps4iu2z5_/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /tmp/tmps4iu2z5_/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmps4iu2z5_/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /tmp/tmps4iu2z5_/-step-0-to-step-1000.mp4
# ℹ Pushing repo 0x46455/ppo-LunarLander-v2 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...-v2/pytorch_variables.pth: 100%|##########| 1.26kB / 1.26kB
#   ...r-v2/policy.optimizer.pth: 100%|##########| 88.7kB / 88.7kB
#   ...LunarLander-v2/policy.pth: 100%|##########| 44.1kB / 44.1kB
#   ...nr/ppo-LunarLander-v2.zip: 100%|##########|  149kB /  149kB
#   ...nr/ppo-LunarLander-v2.zip: 100%|##########|  149kB /  149kB
#   /tmp/tmpt4t1ronr/replay.mp4 : 100%|##########|  163kB /  163kB
#   /tmp/tmpt4t1ronr/replay.mp4 : 100%|##########|  163kB /  163kB
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/0x46455/ppo-LunarLander-v2/tree/main/
# CommitInfo(commit_url='https://huggingface.co/0x46455/ppo-LunarLander-v2/commit/677d472851aea696c0af609b2ff249d39a85c34a', commit_message='Upload PPO LunarLander-v2 trained agent', commit_description='', oid='677d472851aea696c0af609b2ff249d39a85c34a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/0x46455/ppo-LunarLander-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='0x46455/ppo-LunarLander-v2'), pr_revision=None, pr_num=None)

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Reinforcement Learning agent. The script above should have displayed a link to a model repository such as https://huggingface.co/osanseviero/test_sb3. When you go to this link, you can:
# * See a video preview of your agent at the right.
# * Click "Files and versions" to see all the files in the repository.
# * Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# * A model card (`README.md` file) which gives a description of the model
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# Compare the results of your LunarLander-v2 with your classmates using the leaderboard 🏆 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %%
import os
os.kill(os.getpid(), 9)

# %% [markdown]
# ## Load a saved LunarLander model from the Hub 🤗
# Thanks to [ironbar](https://github.com/ironbar) for the contribution.
#
# Loading a saved model from the Hub is really easy.
#
# You go to https://huggingface.co/models?library=stable-baselines3 to see the list of all the Stable-baselines3 saved models.
# 1. You select one and copy its repo_id
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/copy-id.png" alt="Copy-id"/>

# %% [markdown]
# 2. Then we just need to use load_from_hub with:
# - The repo_id
# - The filename: the saved model inside the repo and its extension (*.zip)

# %% [markdown]
# Because the model I download from the Hub was trained with Gym (the former version of Gymnasium) we need to install shimmy a API conversion tool that will help us to run the environment correctly.
#
# Shimmy Documentation: https://github.com/Farama-Foundation/Shimmy

# %%
# !pip install shimmy

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)

# %% [markdown]
# Let's evaluate this agent:

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! As you saw, the current agent is not doing great. As a first suggestion, you can train for more steps. With 1,000,000 steps, we saw some great results!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here are some ideas to achieve so:
# * Train more steps
# * Try different hyperparameters for `PPO`. You can see them at https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters.
# * Check the [Stable-Baselines3 documentation](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) and try another model such as DQN.
# * **Push your new trained model** on the Hub 🔥
#
# **Compare the results of your LunarLander-v2 with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆
#
# Is moon landing too boring for you? Try to **change the environment**, why not use MountainCar-v0, CartPole-v1 or CarRacing-v0? Check how they work [using the gym documentation](https://www.gymlibrary.dev/) and have fun 🎉.

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter! That was the biggest one, **and there was a lot of information.**
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and have a solid foundations.
#
# Naturally, during the course, we’re going to dive deeper into these concepts but **it’s better to have a good understanding of them now before diving into the next chapters.**

# %% [markdown]
# Next time, in the bonus unit 1, you'll train Huggy the Dog to fetch the stick.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/huggy.jpg" alt="Huggy"/>
#
# ## Keep learning, stay awesome 🤗
